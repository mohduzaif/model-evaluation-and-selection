# %% [markdown]
# ### Import Libraries.

# %%
import pandas as pd 
import numpy as np 

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut

# %% [markdown]
# ### Overview of data.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')

# %%
df.sample(5)
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 492   0.11132   0.0  27.74     0  0.609  5.983   83.5  2.1099    4  711
# 60    0.14932  25.0   5.13     0  0.453  5.741   66.2  7.2254    8  284
# 414  45.74610   0.0  18.10     0  0.693  4.519  100.0  1.6582   24  666
# 505   0.04741   0.0  11.93     0  0.573  6.030   80.8  2.5050    1  273
# 477  15.02340   0.0  18.10     0  0.614  5.304   97.3  2.1007   24  666
#
#      ptratio       b  lstat  medv
# 492     20.1  396.90  13.35  20.1
# 60      19.7  395.11  13.15  18.7
# 414     20.2   88.27  36.98   7.0
# 505     21.0  396.90   7.88  11.9
# 477     20.2  349.48  24.91  12.0

# %% [markdown]
# ### Pre-Processing

# %%
# separate the feature and target.

X = df.iloc[ : , 0 : 13]
y = df['medv']

# %%
# train-test-split. 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=90)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### Apply Hold out approach OR train-test split approach.

# %% [markdown]
# This approach is applied to show what is the issue in this approach.

# %%
# model training.

lr_model = LinearRegression()

lr_model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
# testing.
y_pred = lr_model.predict(X_test_scaled)

# %%
# MSE. 
mse = mean_squared_error(y_test, y_pred)

# %%
print('MSE using hold out approach : ', mse)
# Out:
# MSE using hold out approach :  25.971255037472854

# %% [markdown]
# `NOTE : ` This MSE value is changed quite drastically every time, when I change the random_state value means when we suffle the data and do train test split its value is changes quite drastically.

# %% [markdown]
# ### Apply Leave one-out Cross validation.

# %%
# create the model object. 
model = LinearRegression() 

# create the leave one-out cv object. 
loocv = LeaveOneOut() 

# now apply LOOCV. 
scores = cross_val_score(model, X, y, cv=loocv, scoring='neg_mean_squared_error')

# %%
# Invert the sign of the scores
mse_scores = -scores

# Print the mean MSE over all LOOCV iterations
print("Mean MSE:", mse_scores.mean())
# Out:
# Mean MSE: 23.725745519476153

# %% [markdown]
# `NOTE : ` here we see that every time the MSE value remain same, that show the consistency and reliability in results.
